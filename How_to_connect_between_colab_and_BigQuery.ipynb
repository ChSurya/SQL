# %%
from google.colab import auth
auth.authenticate_user()
# For that command this notebook will access our google credentials and google cloud but we also give manual access like clicking allow button for the access

# %%
from google.cloud import bigquery
# we are importing bigquery so we can write the SQL Queries in colab note book

# %%
client = bigquery.Client('scaler-sql-476312')
# we are creating a connection between the colab and BigQuery
# we need to mention our project ID in the client paranthesis then only colab will understand which project i need to make a connection

# %%
query = """
SELECT *
FROM `scaler-sql-476312.farmers_market.product`
"""

df = client.query(query).to_dataframe()
df.head()

# In Query part after parathensis we need to mention the projectID.dataset.table then only query will execute
# Out:
#    product_id                product_name product_size  product_category_id  \
# 0          15        Red Potatoes - Small                                 1
# 1           1  Habanero Peppers - Organic       medium                    1
# 2           2  Jalapeno Peppers - Organic        small                    1
# 3           9              Sweet Potatoes       medium                    1
# 4          13      Baby Salad Lettuce Mix         1 lb                    1
#
#   product_qty_type
# 0             Null
# 1              lbs
# 2              lbs
# 3              lbs
# 4              lbs
